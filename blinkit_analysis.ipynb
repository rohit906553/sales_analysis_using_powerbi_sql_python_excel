# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('BlinKIT Grocery Data.csv')
df
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 1                          2022            OUT018               Tier 3
# ...

# %%
df.head(20)
# Out:
#    Item Fat Content Item Identifier              Item Type  \
# 0           Regular           FDX32  Fruits and Vegetables
# 1           Low Fat           NCB42     Health and Hygiene
# 2           Regular           FDR28           Frozen Foods
# 3           Regular           FDL50                 Canned
# 4           Low Fat           DRI25            Soft Drinks
# 5           low fat           FDS52           Frozen Foods
# 6           Low Fat           NCU05     Health and Hygiene
# 7           Low Fat           NCD30              Household
# 8           Low Fat           FDW20  Fruits and Vegetables
# 9           Low Fat           FDX25                 Canned
# 10               LF           FDX21            Snack Foods
# 11          Low Fat           NCU41     Health and Hygiene
# 12          Low Fat           FDL20  Fruits and Vegetables
# 13          Low Fat           NCR54              Household
# 14          Low Fat           FDH19                   Meat
# ...

# %%
df.tail(10)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8513                       1998            OUT027               Tier 3
# 8514                       1998            OUT027               Tier 3
# 8515                       1998            OUT027               Tier 3
# ...

# %%
print("size of data:",df.shape)
# Out:
# size of data: (8523, 12)

# %%
df.ndim
# Out:
# 2

# %%
df.columns #feild info
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
#  data cleaning

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %%
df['Item Fat Content'] = df['Item Fat Content'].replace({'LF':'Low Fat'})
df['Item Fat Content'] = df['Item Fat Content'].replace({'low fat':'Low Fat'})
df['Item Fat Content'] = df['Item Fat Content'].replace({'reg':'Regular'})

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat']

# %% [markdown]
# kpi's requirements

# %%
#total sales
total_sales= df['Sales'].sum()
print(f"Total sales: $ {total_sales:,.0f}")
# Out:
# Total sales: $ 1,201,681

# %%
avg_sales = df['Sales'].mean()
print(f"Average sales: $ {avg_sales:,.1f}")
# Out:
# Average sales: $ 141.0

# %%
no_of_items_sold = df['Sales'].count()
print(f"No of Items Sold: {no_of_items_sold:,.0f}")
# Out:
# No of Items Sold: 8,523

# %%
avg_ratings= df['Rating'].mean()
print(f"Average ratings:  {avg_ratings:,.1f}")
# Out:
# Average ratings:  4.0

# %%
sales_by_fat = df.groupby('Item Fat Content')['Sales'].sum()
plt.pie(sales_by_fat, labels= sales_by_fat.index, autopct='%.0f%%', startangle=90)
plt.title('Sales by Fat Content')
plt.axis('equal')
plt.show()

# %%
Avg_sales_by_fat = df.groupby('Item Fat Content')['Sales'].mean()
plt.pie(Avg_sales_by_fat, labels= Avg_sales_by_fat.index, autopct='%.1f%%', startangle=90)
plt.title('Avg Sales by Fat Content')
plt.axis('equal')
plt.show()

# %%
no_of_items_sold_by_fat = df.groupby('Item Fat Content')['Sales'].count()
plt.pie(no_of_items_sold_by_fat, labels= no_of_items_sold_by_fat.index, autopct='%.0f%%', startangle=90)
plt.title('no of items sold by Fat Content')
plt.axis('equal')
plt.show()

# %%
Avg_ratings_by_fat = df.groupby('Item Fat Content')['Rating'].mean()
plt.pie(Avg_ratings_by_fat, labels= Avg_ratings_by_fat.index, autopct='%.2f%%', startangle=90)
plt.title('Avg Ratings by Fat Content')
plt.axis('equal')
plt.show()

# %%
sales_by_type = df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
bars = plt.bar(sales_by_type.index, sales_by_type.values)
plt.xticks(rotation = -90)
plt.xlabel('Item Type')
plt.ylabel('Total Sales')
plt.title('Total Sales by Item Type')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():,.0f}', ha='center', va='bottom',fontsize =8)
plt.tight_layout()
plt.show()

# %%
avg_sales_by_type = df.groupby('Item Type')['Sales'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
bars = plt.bar(avg_sales_by_type.index, avg_sales_by_type.values)
plt.xticks(rotation = -90)
plt.xlabel('Item Type')
plt.ylabel('average Sales')
plt.title('average Sales by Item Type')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():,.0f}', ha='center', va='bottom',fontsize =8)
plt.tight_layout()
plt.show()

# %%
no_of_items_sold_by_type = df.groupby('Item Type')['Sales'].count().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
bars = plt.bar(no_of_items_sold_by_type.index, no_of_items_sold_by_type.values)
plt.xticks(rotation = -90)
plt.xlabel('Item Type')
plt.ylabel('no of items sold')
plt.title('no of items sold by Item Type')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():,.0f}', ha='center', va='bottom',fontsize =8)
plt.tight_layout()
plt.show()

# %%
avg_ratings_by_type = df.groupby('Item Type')['Rating'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
bars = plt.bar(avg_ratings_by_type.index, avg_ratings_by_type.values)
plt.xticks(rotation = -90)
plt.xlabel('Item Type')
plt.ylabel('average rating')
plt.title('average rating by Item Type')
for bar in bars:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():,.2f}', ha='center', va='bottom',fontsize =8)
plt.tight_layout()
plt.show()

# %% [markdown]
# fat content by outlet for total sales

# %%
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].sum().unstack() 
grouped = grouped[['Regular', 'Low Fat']]  # Reorder columns
ax= grouped.plot(kind='bar',figsize =(8,5), title = 'Outlet Tier by  Item Fat content')
plt.xlabel('Outlet Location Tier')
plt.ylabel('Total Sales')
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %%
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].mean().unstack() 
grouped = grouped[['Regular', 'Low Fat']]  # Reorder columns
ax= grouped.plot(kind='bar',figsize =(8,5), title = 'Outlet Tier by  Item Fat content')
plt.xlabel('Outlet Location Tier')
plt.ylabel('avg Sales')
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %%
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].count().unstack() 
grouped = grouped[['Regular', 'Low Fat']]  # Reorder columns
ax= grouped.plot(kind='bar',figsize =(8,5), title = 'Outlet Tier by  Item Fat content')
plt.xlabel('Outlet Location Tier')
plt.ylabel('No of items sold')
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %%
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Rating'].mean().unstack() 
grouped = grouped[['Regular', 'Low Fat']]  # Reorder columns
ax= grouped.plot(kind='bar',figsize =(8,5), title = 'Outlet Tier by  Item Fat content')
plt.xlabel('Outlet Location Tier')
plt.ylabel('Average Ratings')
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %% [markdown]
# total sales by outlet establishment

# %%
sales_by_year = df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()
plt.figure(figsize=(9, 5))
plt.plot(sales_by_year.index, sales_by_year.values, marker='o', linestyle='-')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Total Sales')
plt.title('Total Sales by Outlet Establishment Year')
for x,y in zip(sales_by_year.index, sales_by_year.values):
    plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\rohit\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
avg_sales_by_year = df.groupby('Outlet Establishment Year')['Sales'].mean().sort_index()
plt.figure(figsize=(9, 5))
plt.plot(avg_sales_by_year.index, avg_sales_by_year.values, marker='o', linestyle='-')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Average Sales')
plt.title('Average Sales by Outlet Establishment Year')
for x,y in zip(avg_sales_by_year.index, avg_sales_by_year.values):
    plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\rohit\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
no_of_items_sold_by_year = df.groupby('Outlet Establishment Year')['Sales'].count().sort_index()
plt.figure(figsize=(9, 5))
plt.plot(no_of_items_sold_by_year.index, no_of_items_sold_by_year.values, marker='o', linestyle='-')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('no of items sold')
plt.title('no of items sold by Outlet Establishment Year')
for x,y in zip(no_of_items_sold_by_year.index, no_of_items_sold_by_year.values):
    plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\rohit\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
avg_ratings_by_year = df.groupby('Outlet Establishment Year')['Rating'].mean().sort_index()
plt.figure(figsize=(9, 5))
plt.plot(avg_ratings_by_year.index, avg_ratings_by_year.values, marker='o', linestyle='-')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Average Ratings')
plt.title('Average Ratings by Outlet Establishment Year')
for x,y in zip(avg_ratings_by_year.index, avg_ratings_by_year.values):
    plt.text(x, y, f'{y:,.2f}', ha='center', va='bottom', fontsize=8)
plt.tight_layout()
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\rohit\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# sales by outlet size

# %%
sales_by_size = df.groupby('Outlet Size')['Sales'].sum()
plt.figure(figsize=(4, 4))
plt.pie(sales_by_size, labels = sales_by_size.index, autopct='%1.1f%%', startangle=90)
plt.title('Sales by Outlet Size')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
avg_sales_by_size = df.groupby('Outlet Size')['Sales'].mean()
plt.figure(figsize=(4, 4))
plt.pie(avg_sales_by_size, labels = avg_sales_by_size.index, autopct='%1.1f%%', startangle=90)
plt.title('average Sales by Outlet Size')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
no_of_items_sold_by_size = df.groupby('Outlet Size')['Sales'].count()
plt.figure(figsize=(4, 4))
plt.pie(no_of_items_sold_by_size, labels=no_of_items_sold_by_size.index, autopct='%1.1f%%', startangle=90)
plt.title('no of items sold by Outlet Size')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
avg_ratings_by_size = df.groupby('Outlet Size')['Rating'].mean()
plt.figure(figsize=(4, 4))
plt.pie(avg_ratings_by_size, labels=avg_ratings_by_size.index, autopct='%1.1f%%', startangle=90)
plt.title('average Ratings by Outlet Size')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# sales by outlet location

# %%
sales_by_location = df.groupby('Outlet Location Type')['Sales'].sum().reset_index()
sales_by_location = sales_by_location.sort_values('Sales', ascending=False)
plt.figure(figsize=(8, 5))#smaller height, enough width
ax = sns.barplot(x='Sales', y='Outlet Location Type', data = sales_by_location)
plt.title('Sales by Outlet Location Type')
plt.xlabel('Total Sales')       
plt.ylabel('Outlet Location Type')
plt.tight_layout()
plt.show()

# %%
avg_sales_by_location = df.groupby('Outlet Location Type')['Sales'].mean().reset_index()
avg_sales_by_location = avg_sales_by_location.sort_values('Sales', ascending=False)
plt.figure(figsize=(8, 5))#smaller height, enough width
ax = sns.barplot(x='Sales', y='Outlet Location Type', data = avg_sales_by_location)
plt.title('average Sales by Outlet Location Type')
plt.xlabel('average Sales')       
plt.ylabel('Outlet Location Type')
plt.tight_layout()
plt.show()

# %%
no_of_items_sold_by_location = df.groupby('Outlet Location Type')['Sales'].count().reset_index()
no_of_items_sold_by_location = no_of_items_sold_by_location.sort_values('Sales', ascending=False)
plt.figure(figsize=(8, 5))#smaller height, enough width
ax = sns.barplot(x='Sales', y='Outlet Location Type', data = no_of_items_sold_by_location)
plt.title('no of items sold by Outlet Location Type')
plt.xlabel('no of items sold')       
plt.ylabel('Outlet Location Type')
plt.tight_layout()
plt.show()

# %%
average_rating_by_location = df.groupby('Outlet Location Type')['Rating'].mean().reset_index()
average_rating_by_location = average_rating_by_location.sort_values('Rating', ascending=False)
plt.figure(figsize=(8, 5))#smaller height, enough width
ax = sns.barplot(x='Rating', y='Outlet Location Type', data = average_rating_by_location)
plt.title('average rating by Outlet Location Type')
plt.xlabel('average rating')       
plt.ylabel('Outlet Location Type')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18252\1166366538.py in ?()
#       1 average_rating_by_location = df.groupby('Outlet Location Type')['Rating'].mean().reset_index()
# ----> 2 average_rating_by_location = average_rating_by_location.sort_values('Sales', ascending=False)
#       3 plt.figure(figsize=(8, 5))#smaller height, enough width
#       4 ax = sns.barplot(x='Sales', y='Outlet Location Type', data = average_rating_by_location)
#       5 plt.title('average rating by Outlet Location Type')
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7192             )
#    7193         elif len(by):
#    7194             # len(by) == 1
#    7195
# -> 7196             k = self._get_label_or_level_values(by[0], axis=axis)
#    7197
# ...
